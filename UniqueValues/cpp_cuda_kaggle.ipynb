# %%
# !git clone https://github.com/Flagro/ParallelTasks.git
# Out:
# fatal: destination path 'ParallelTasks' already exists and is not an empty directory.

# %%
# %cd /kaggle/working/ParallelTasks
# !git pull origin main
# Out:
# /kaggle/working/ParallelTasks
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 7 (delta 5), reused 6 (delta 4), pack-reused 0
# Unpacking objects: 100% (7/7), 1.21 KiB | 620.00 KiB/s, done.
# From https://github.com/Flagro/ParallelTasks
#  * branch            main       -> FETCH_HEAD
#    8cf12cc..e370021  main       -> origin/main
# Updating 8cf12cc..e370021
# Fast-forward
#  README.md            | 8 ++++++--
#  UniqueValues/main.cu | 2 +-
#  2 files changed, 7 insertions(+), 3 deletions(-)

# %%
# %cd /kaggle/working/ParallelTasks/UniqueValues/
# Out:
# /kaggle/working/ParallelTasks/UniqueValues

# %%
# !git pull origin main
# !chmod +x run.sh
# !./run.sh
# Out:
# From https://github.com/Flagro/ParallelTasks
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# mkdir: cannot create directory ‘build’: File exists
# cmake: /opt/conda/lib/libcurl.so.4: no version information available (required by cmake)
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /kaggle/working/ParallelTasks/UniqueValues/build
# /usr/bin/cmake: /opt/conda/lib/libcurl.so.4: no version information available (required by /usr/bin/cmake)
# /usr/bin/cmake: /opt/conda/lib/libcurl.so.4: no version information available (required by /usr/bin/cmake)
# /usr/bin/cmake: /opt/conda/lib/libcurl.so.4: no version information available (required by /usr/bin/cmake)
# Consolidate compiler generated dependencies of target UniqueFinder
# /usr/bin/cmake: /opt/conda/lib/libcurl.so.4: no version information available (required by /usr/bin/cmake)
# [ 33%] Building CUDA object CMakeFiles/UniqueFinder.dir/main.cu.o
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !nvidia-smi
# Out:
# Sun Oct 29 01:10:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.161.03   Driver Version: 470.161.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
